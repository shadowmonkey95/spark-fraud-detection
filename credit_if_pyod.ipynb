# %%
from pyspark.sql import SparkSession
from pyspark.ml.feature import StandardScaler, VectorAssembler
from pyspark.sql.functions import col, pandas_udf, PandasUDFType
import pyspark.sql.functions as F
import pandas as pd
import numpy as np
from pyod.models.iforest import IForest
from pyspark.sql.types import ArrayType, DoubleType
from sklearn.metrics import (
    precision_recall_curve, 
    average_precision_score, 
    roc_auc_score, 
    confusion_matrix, 
    classification_report
)
import logging
logging.basicConfig(level=logging.INFO)
try:
    spark = SparkSession.builder.appName("FraudDetection").getOrCreate()
    spark.sparkContext.setLogLevel("DEBUG")
    print(spark.version)

    df = spark.read.csv("./data/creditcard.csv", header=True, inferSchema=True)
    df = df.drop("Time")

    # Separate fraud and non-fraud transactions
    non_fraud_df = df.filter(col("Class") == 0)
    fraud_df = df.filter(col("Class") == 1)

    feature_columns = [
        col for col in df.columns 
        if col not in ['Class']
    ]

    # Assemble features into a vector for non-fraud data
    assembler = VectorAssembler(inputCols=feature_columns, outputCol="raw_features")
    assembled_non_fraud_df = assembler.transform(non_fraud_df)

    # Scale the features
    scaler = StandardScaler(inputCol="raw_features", outputCol="scaled_features", withStd=True, withMean=True)
    scaler_model = scaler.fit(assembled_non_fraud_df)
    scaled_non_fraud_df = scaler_model.transform(assembled_non_fraud_df)

    # Convert scaling model to full dataset
    scaled_full_df = scaler_model.transform(assembler.transform(df))

    # Convert scaled features to list
    def vector_to_list(vector):
        """Convert Spark Vector to list"""
        return vector.toArray().tolist()

    vector_to_list_udf = F.udf(vector_to_list, ArrayType(DoubleType()))

    scaled_non_fraud_df = scaled_non_fraud_df.withColumn("scaled_features_list", 
                                    vector_to_list_udf(F.col("scaled_features")))
    scaled_full_df = scaled_full_df.withColumn("scaled_features_list", 
                                    vector_to_list_udf(F.col("scaled_features")))

    # Extract numpy array of features for PyOD
    non_fraud_features = scaled_non_fraud_df.select("scaled_features_list").toPandas()
    non_fraud_features_array = np.array(non_fraud_features["scaled_features_list"].tolist())

    # Full dataset features for evaluation
    full_features = scaled_full_df.select("scaled_features_list", "Class").toPandas()
    full_features_array = np.array(full_features["scaled_features_list"].tolist())
    true_labels = full_features["Class"].values

    # Train PyOD model
    model = IForest(random_state=42, contamination=0.01)  # Set expected fraud rate
    model.fit(non_fraud_features_array)

    # Predict on full dataset
    predictions = model.predict(full_features_array)
    scores = model.decision_function(full_features_array)

    # Evaluation Metrics
    def print_evaluation_metrics(y_true, y_pred, scores):
        """
        Compute and print various evaluation metrics
        
        Parameters:
        - y_true: True labels
        - y_pred: Predicted labels
        - scores: Anomaly scores
        """
        print("\n--- Fraud Detection Evaluation Metrics ---")
        
        # Confusion Matrix
        cm = confusion_matrix(y_true, y_pred)
        print("\nConfusion Matrix:")
        print(cm)
        
        # Classification Report
        print("\nClassification Report:")
        print(classification_report(y_true, y_pred))
        
        # Area Under Precision-Recall Curve (AUPRC)
        precision, recall, _ = precision_recall_curve(y_true, scores)
        auprc = average_precision_score(y_true, scores)
        print(f"\nArea Under Precision-Recall Curve (AUPRC): {auprc:.4f}")
        
        # ROC AUC Score
        roc_auc = roc_auc_score(y_true, scores)
        print(f"ROC AUC Score: {roc_auc:.4f}")
        
        # Detailed Fraud Detection Performance
        fraud_mask = y_true == 1
        non_fraud_mask = y_true == 0
        
        print("\nFraud Detection Performance:")
        print(f"Total Transactions: {len(y_true)}")
        print(f"Fraud Transactions: {sum(fraud_mask)}")
        print(f"Non-Fraud Transactions: {sum(non_fraud_mask)}")
        
        fraud_predictions = y_pred[fraud_mask]
        print(f"Correctly Detected Fraud: {sum(fraud_predictions)} out of {sum(fraud_mask)}")
        print(f"Fraud Detection Rate: {sum(fraud_predictions) / sum(fraud_mask):.4f}")

    # Run evaluation
    print_evaluation_metrics(true_labels, predictions, scores)
finally:
    # Stop Spark Session
    spark.stop()
# Out:
# your 131072x1 screen size is bogus. expect trouble
# 24/12/11 22:41:24 WARN Utils: Your hostname, KrystalXPS resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 24/12/11 22:41:24 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/12/11 22:41:39 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 24/12/11 22:41:44 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 3.5.3
# 24/12/11 22:41:48 DEBUG FileSystem: Loading filesystems
# 24/12/11 22:41:48 DEBUG FileSystem: nullscan:// = class org.apache.hadoop.hive.ql.io.NullScanFileSystem from /home/vuphamas/code/fx/venv/lib/python3.10/site-packages/pyspark/jars/hive-exec-2.3.9-core.jar
# 24/12/11 22:41:48 DEBUG FileSystem: file:// = class org.apache.hadoop.fs.LocalFileSystem from /home/vuphamas/code/fx/venv/lib/python3.10/site-packages/pyspark/jars/hadoop-client-api-3.3.4.jar
# 24/12/11 22:41:48 DEBUG FileSystem: file:// = class org.apache.hadoop.hive.ql.io.ProxyLocalFileSystem from /home/vuphamas/code/fx/venv/lib/python3.10/site-packages/pyspark/jars/hive-exec-2.3.9-core.jar
# 24/12/11 22:41:48 DEBUG FileSystem: viewfs:// = class org.apache.hadoop.fs.viewfs.ViewFileSystem from /home/vuphamas/code/fx/venv/lib/python3.10/site-packages/pyspark/jars/hadoop-client-api-3.3.4.jar
# 24/12/11 22:41:48 DEBUG FileSystem: har:// = class org.apache.hadoop.fs.HarFileSystem from /home/vuphamas/code/fx/venv/lib/python3.10/site-packages/pyspark/jars/hadoop-client-api-3.3.4.jar
# 24/12/11 22:41:48 DEBUG FileSystem: http:// = class org.apache.hadoop.fs.http.HttpFileSystem from /home/vuphamas/code/fx/venv/lib/python3.10/site-packages/pyspark/jars/hadoop-client-api-3.3.4.jar
# 24/12/11 22:41:48 DEBUG FileSystem: https:// = class org.apache.hadoop.fs.http.HttpsFileSystem from /home/vuphamas/code/fx/venv/lib/python3.10/site-packages/pyspark/jars/hadoop-client-api-3.3.4.jar
# 24/12/11 22:41:48 DEBUG FileSystem: hdfs:// = class org.apache.hadoop.hdfs.DistributedFileSystem from /home/vuphamas/code/fx/venv/lib/python3.10/site-packages/pyspark/jars/hadoop-client-api-3.3.4.jar
# 24/12/11 22:41:48 DEBUG FileSystem: webhdfs:// = class org.apache.hadoop.hdfs.web.WebHdfsFileSystem from /home/vuphamas/code/fx/venv/lib/python3.10/site-packages/pyspark/jars/hadoop-client-api-3.3.4.jar
# 24/12/11 22:41:48 DEBUG FileSystem: swebhdfs:// = class org.apache.hadoop.hdfs.web.SWebHdfsFileSystem from /home/vuphamas/code/fx/venv/lib/python3.10/site-packages/pyspark/jars/hadoop-client-api-3.3.4.jar
# 24/12/11 22:41:48 DEBUG FileSystem: Looking for FS supporting file
# 24/12/11 22:41:48 DEBUG FileSystem: looking for configuration option fs.file.impl
# 24/12/11 22:41:48 DEBUG FileSystem: Looking in service filesystems for implementation class
# 24/12/11 22:41:48 DEBUG FileSystem: FS for file is class org.apache.hadoop.hive.ql.io.ProxyLocalFileSystem
# 24/12/11 22:41:48 INFO SharedState: Setting hive.metastore.warehouse.dir ('null') to the value of spark.sql.warehouse.dir.
# 24/12/11 22:41:48 DEBUG SharedState: Applying other initial session options to HadoopConf: spark.app.name -> FraudDetection
# 24/12/11 22:41:48 DEBUG FileSystem: Starting: Acquiring creator semaphore for file:/home/vuphamas/code/fraud/spark-warehouse
# 24/12/11 22:41:48 DEBUG FileSystem: Acquiring creator semaphore for file:/home/vuphamas/code/fraud/spark-warehouse: duration 0:00.001s
# 24/12/11 22:41:48 DEBUG FileSystem: Starting: Creating FS file:/home/vuphamas/code/fraud/spark-warehouse
# 24/12/11 22:41:48 DEBUG FileSystem: Looking for FS supporting file
# 24/12/11 22:41:48 DEBUG FileSystem: looking for configuration option fs.file.impl
# 24/12/11 22:41:48 DEBUG FileSystem: Looking in service filesystems for implementation class
# 24/12/11 22:41:48 DEBUG FileSystem: FS for file is class org.apache.hadoop.hive.ql.io.ProxyLocalFileSystem
# 24/12/11 22:41:48 DEBUG FileSystem: Creating FS file:/home/vuphamas/code/fraud/spark-warehouse: duration 0:00.029s
# 24/12/11 22:41:48 INFO SharedState: Warehouse path is 'file:/home/vuphamas/code/fraud/spark-warehouse'.
# 24/12/11 22:41:48 DEBUG FsUrlStreamHandlerFactory: Creating handler for protocol jar
# 24/12/11 22:41:48 DEBUG FileSystem: Looking for FS supporting jar
# 24/12/11 22:41:48 DEBUG FileSystem: looking for configuration option fs.jar.impl
# 24/12/11 22:41:48 DEBUG FileSystem: Looking in service filesystems for implementation class
# 24/12/11 22:41:48 DEBUG FsUrlStreamHandlerFactory: Unknown protocol jar, delegating to default implementation
# 24/12/11 22:41:51 DEBUG DataSource: Some paths were ignored:
#
# 24/12/11 22:41:51 INFO InMemoryFileIndex: It took 219 ms to list leaf files for 1 paths.
# 24/12/11 22:41:52 INFO InMemoryFileIndex: It took 10 ms to list leaf files for 1 paths.
# 24/12/11 22:41:52 DEBUG CatalystSqlParser: Parsing command: spark_grouping_id
# 24/12/11 22:41:53 DEBUG Analyzer$ResolveReferences: Resolving 'value to value#0
# 24/12/11 22:41:56 DEBUG Analyzer$ResolveReferences: Resolving 'value to value#7
# 24/12/11 22:41:57 INFO FileSourceStrategy: Pushed Filters:
# 24/12/11 22:41:57 INFO FileSourceStrategy: Post-Scan Filters: (length(trim(value#0, None)) > 0)
# 24/12/11 22:41:57 DEBUG WholeStageCodegenExec:
# /* 001 */ public Object generate(Object[] references) {
# /* 002 */   return new GeneratedIteratorForCodegenStage1(references);
# /* 003 */ }
# /* 004 */
# /* 005 */ // codegenStageId=1
# /* 006 */ final class GeneratedIteratorForCodegenStage1 extends org.apache.spark.sql.execution.BufferedRowIterator {
# /* 007 */   private Object[] references;
# /* 008 */   private scala.collection.Iterator[] inputs;
# /* 009 */   private scala.collection.Iterator inputadapter_input_0;
# /* 010 */   private org.apache.spark.sql.catalyst.expressions.codegen.UnsafeRowWriter[] filter_mutableStateArray_0 = new org.apache.spark.sql.catalyst.expressions.codegen.UnsafeRowWriter[1];
# /* 011 */
# /* 012 */   public GeneratedIteratorForCodegenStage1(Object[] references) {
# /* 013 */     this.references = references;
# /* 014 */   }
# /* 015 */
# /* 016 */   public void init(int index, scala.collection.Iterator[] inputs) {
# /* 017 */     partitionIndex = index;
# /* 018 */     this.inputs = inputs;
# /* 019 */     inputadapter_input_0 = inputs[0];
# /* 020 */     filter_mutableStateArray_0[0] = new org.apache.spark.sql.catalyst.expressions.codegen.UnsafeRowWriter(1, 32);
# /* 021 */
# /* 022 */   }
# /* 023 */
# /* 024 */   protected void processNext() throws java.io.IOException {
# /* 025 */     while ( inputadapter_input_0.hasNext()) {
# /* 026 */       InternalRow inputadapter_row_0 = (InternalRow) inputadapter_input_0.next();
# /* 027 */
# /* 028 */       do {
# /* 029 */         boolean inputadapter_isNull_0 = inputadapter_row_0.isNullAt(0);
# /* 030 */         UTF8String inputadapter_value_0 = inputadapter_isNull_0 ?
# /* 031 */         null : (inputadapter_row_0.getUTF8String(0));
# /* 032 */
# /* 033 */         boolean filter_isNull_0 = true;
# /* 034 */         boolean filter_value_0 = false;
# /* 035 */         boolean filter_isNull_2 = false;
# /* 036 */         UTF8String filter_value_2 = null;
# /* 037 */         if (inputadapter_isNull_0) {
# /* 038 */           filter_isNull_2 = true;
# /* 039 */         } else {
# /* 040 */           filter_value_2 = inputadapter_value_0.trim();
# /* 041 */         }
# /* 042 */         boolean filter_isNull_1 = filter_isNull_2;
# /* 043 */         int filter_value_1 = -1;
# /* 044 */
# /* 045 */         if (!filter_isNull_2) {
# /* 046 */           filter_value_1 = (filter_value_2).numChars();
# /* 047 */         }
# /* 048 */         if (!filter_isNull_1) {
# /* 049 */           filter_isNull_0 = false; // resultCode could change nullability.
# /* 050 */           filter_value_0 = filter_value_1 > 0;
# /* 051 */
# /* 052 */         }
# /* 053 */         if (filter_isNull_0 || !filter_value_0) continue;
# /* 054 */
# /* 055 */         ((org.apache.spark.sql.execution.metric.SQLMetric) references[0] /* numOutputRows */).add(1);
# /* 056 */
# /* 057 */         filter_mutableStateArray_0[0].reset();
# /* 058 */
# /* 059 */         filter_mutableStateArray_0[0].zeroOutNullBytes();
# /* 060 */
# /* 061 */         if (inputadapter_isNull_0) {
# /* 062 */           filter_mutableStateArray_0[0].setNullAt(0);
# /* 063 */         } else {
# /* 064 */           filter_mutableStateArray_0[0].write(0, inputadapter_value_0);
# /* 065 */         }
# /* 066 */         append((filter_mutableStateArray_0[0].getRow()));
# /* 067 */
# /* 068 */       } while(false);
# /* 069 */       if (shouldStop()) return;
# /* 070 */     }
# /* 071 */   }
# /* 072 */
# /* 073 */ }
#
# 24/12/11 22:41:57 DEBUG CodeGenerator:
# /* 001 */ public Object generate(Object[] references) {
# /* 002 */   return new GeneratedIteratorForCodegenStage1(references);
# /* 003 */ }
# /* 004 */
# /* 005 */ // codegenStageId=1
# /* 006 */ final class GeneratedIteratorForCodegenStage1 extends org.apache.spark.sql.execution.BufferedRowIterator {
# /* 007 */   private Object[] references;
# /* 008 */   private scala.collection.Iterator[] inputs;
# /* 009 */   private scala.collection.Iterator inputadapter_input_0;
# /* 010 */   private org.apache.spark.sql.catalyst.expressions.codegen.UnsafeRowWriter[] filter_mutableStateArray_0 = new org.apache.spark.sql.catalyst.expressions.codegen.UnsafeRowWriter[1];
# /* 011 */
# /* 012 */   public GeneratedIteratorForCodegenStage1(Object[] references) {
# /* 013 */     this.references = references;
# /* 014 */   }
# /* 015 */
# /* 016 */   public void init(int index, scala.collection.Iterator[] inputs) {
# /* 017 */     partitionIndex = index;
# /* 018 */     this.inputs = inputs;
# /* 019 */     inputadapter_input_0 = inputs[0];
# /* 020 */     filter_mutableStateArray_0[0] = new org.apache.spark.sql.catalyst.expressions.codegen.UnsafeRowWriter(1, 32);
# /* 021 */
# /* 022 */   }
# /* 023 */
# /* 024 */   protected void processNext() throws java.io.IOException {
# /* 025 */     while ( inputadapter_input_0.hasNext()) {
# /* 026 */       InternalRow inputadapter_row_0 = (InternalRow) inputadapter_input_0.next();
# /* 027 */
# /* 028 */       do {
# /* 029 */         boolean inputadapter_isNull_0 = inputadapter_row_0.isNullAt(0);
# /* 030 */         UTF8String inputadapter_value_0 = inputadapter_isNull_0 ?
# /* 031 */         null : (inputadapter_row_0.getUTF8String(0));
# /* 032 */
# /* 033 */         boolean filter_isNull_0 = true;
# /* 034 */         boolean filter_value_0 = false;
# /* 035 */         boolean filter_isNull_2 = false;
# /* 036 */         UTF8String filter_value_2 = null;
# /* 037 */         if (inputadapter_isNull_0) {
# /* 038 */           filter_isNull_2 = true;
# /* 039 */         } else {
# /* 040 */           filter_value_2 = inputadapter_value_0.trim();
# /* 041 */         }
# /* 042 */         boolean filter_isNull_1 = filter_isNull_2;
# /* 043 */         int filter_value_1 = -1;
# /* 044 */
# /* 045 */         if (!filter_isNull_2) {
# /* 046 */           filter_value_1 = (filter_value_2).numChars();
# /* 047 */         }
# /* 048 */         if (!filter_isNull_1) {
# /* 049 */           filter_isNull_0 = false; // resultCode could change nullability.
# /* 050 */           filter_value_0 = filter_value_1 > 0;
# /* 051 */
# /* 052 */         }
# /* 053 */         if (filter_isNull_0 || !filter_value_0) continue;
# /* 054 */
# /* 055 */         ((org.apache.spark.sql.execution.metric.SQLMetric) references[0] /* numOutputRows */).add(1);
# /* 056 */
# /* 057 */         filter_mutableStateArray_0[0].reset();
# /* 058 */
# /* 059 */         filter_mutableStateArray_0[0].zeroOutNullBytes();
# /* 060 */
# /* 061 */         if (inputadapter_isNull_0) {
# /* 062 */           filter_mutableStateArray_0[0].setNullAt(0);
# /* 063 */         } else {
# /* 064 */           filter_mutableStateArray_0[0].write(0, inputadapter_value_0);
# /* 065 */         }
# /* 066 */         append((filter_mutableStateArray_0[0].getRow()));
# /* 067 */
# /* 068 */       } while(false);
# /* 069 */       if (shouldStop()) return;
# /* 070 */     }
# /* 071 */   }
# /* 072 */
# /* 073 */ }
#
# 24/12/11 22:41:58 INFO CodeGenerator: Code generated in 479.444293 ms
# 24/12/11 22:41:58 INFO MemoryStore: Block broadcast_0 stored as values in memory (estimated size 199.8 KiB, free 434.2 MiB)
# 24/12/11 22:41:58 DEBUG BlockManager: Put block broadcast_0 locally took 104 ms
# 24/12/11 22:41:58 DEBUG BlockManager: Putting block broadcast_0 without replication took 107 ms
# 24/12/11 22:41:58 INFO MemoryStore: Block broadcast_0_piece0 stored as bytes in memory (estimated size 34.4 KiB, free 434.2 MiB)
# 24/12/11 22:41:58 DEBUG BlockManagerMasterEndpoint: Updating block info on master broadcast_0_piece0 for BlockManagerId(driver, 10.255.255.254, 36101, None)
# 24/12/11 22:41:58 INFO BlockManagerInfo: Added broadcast_0_piece0 in memory on 10.255.255.254:36101 (size: 34.4 KiB, free: 434.4 MiB)
# 24/12/11 22:41:58 DEBUG BlockManagerMaster: Updated info of block broadcast_0_piece0
# 24/12/11 22:41:58 DEBUG BlockManager: Told master about block broadcast_0_piece0
# 24/12/11 22:41:58 DEBUG BlockManager: Put block broadcast_0_piece0 locally took 11 ms
# 24/12/11 22:41:58 DEBUG BlockManager: Putting block broadcast_0_piece0 without replication took 11 ms
# 24/12/11 22:41:58 INFO SparkContext: Created broadcast 0 from csv at NativeMethodAccessorImpl.java:0
# 24/12/11 22:41:58 INFO FileSourceScanExec: Planning scan with bin packing, max size: 19377882 bytes, open cost is considered as scanning 4194304 bytes.
# 24/12/11 22:41:58 DEBUG ClosureCleaner: Cleaning indylambda closure: $anonfun$doExecute$4$adapted
# 24/12/11 22:41:58 DEBUG ClosureCleaner:  +++ indylambda closure ($anonfun$doExecute$4$adapted) is now cleaned +++
# 24/12/11 22:41:58 DEBUG ClosureCleaner: Cleaning indylambda closure: $anonfun$executeTake$2
# 24/12/11 22:41:58 DEBUG ClosureCleaner:  +++ indylambda closure ($anonfun$executeTake$2) is now cleaned +++
# 24/12/11 22:41:58 DEBUG ClosureCleaner: Cleaning indylambda closure: $anonfun$runJob$5
# 24/12/11 22:41:58 DEBUG ClosureCleaner:  +++ indylambda closure ($anonfun$runJob$5) is now cleaned +++
# 24/12/11 22:41:58 INFO SparkContext: Starting job: csv at NativeMethodAccessorImpl.java:0
# 24/12/11 22:41:58 DEBUG DAGScheduler: eagerlyComputePartitionsForRddAndAncestors for RDD 3 took 0.001304 seconds
# 24/12/11 22:41:58 DEBUG DAGScheduler: Merging stage rdd profiles: Set()
# 24/12/11 22:41:58 INFO DAGScheduler: Got job 0 (csv at NativeMethodAccessorImpl.java:0) with 1 output partitions
# 24/12/11 22:41:58 INFO DAGScheduler: Final stage: ResultStage 0 (csv at NativeMethodAccessorImpl.java:0)
# 24/12/11 22:41:58 INFO DAGScheduler: Parents of final stage: List()
# 24/12/11 22:41:58 INFO DAGScheduler: Missing parents: List()
# 24/12/11 22:41:58 DEBUG DAGScheduler: submitStage(ResultStage 0 (name=csv at NativeMethodAccessorImpl.java:0;jobs=0))
# 24/12/11 22:41:58 DEBUG DAGScheduler: missing: List()
# 24/12/11 22:41:58 INFO DAGScheduler: Submitting ResultStage 0 (MapPartitionsRDD[3] at csv at NativeMethodAccessorImpl.java:0), which has no missing parents
# 24/12/11 22:41:58 DEBUG DAGScheduler: submitMissingTasks(ResultStage 0)
# 24/12/11 22:41:58 INFO MemoryStore: Block broadcast_1 stored as values in memory (estimated size 13.5 KiB, free 434.2 MiB)
# 24/12/11 22:41:58 DEBUG BlockManager: Put block broadcast_1 locally took 2 ms
# 24/12/11 22:41:58 DEBUG BlockManager: Putting block broadcast_1 without replication took 2 ms
# 24/12/11 22:41:58 INFO MemoryStore: Block broadcast_1_piece0 stored as bytes in memory (estimated size 6.4 KiB, free 434.2 MiB)
# 24/12/11 22:41:58 DEBUG BlockManagerMasterEndpoint: Updating block info on master broadcast_1_piece0 for BlockManagerId(driver, 10.255.255.254, 36101, None)
# 24/12/11 22:41:58 INFO BlockManagerInfo: Added broadcast_1_piece0 in memory on 10.255.255.254:36101 (size: 6.4 KiB, free: 434.4 MiB)
# 24/12/11 22:41:58 DEBUG BlockManagerMaster: Updated info of block broadcast_1_piece0
# 24/12/11 22:41:58 DEBUG BlockManager: Told master about block broadcast_1_piece0
# 24/12/11 22:41:58 DEBUG BlockManager: Put block broadcast_1_piece0 locally took 2 ms
# 24/12/11 22:41:58 DEBUG BlockManager: Putting block broadcast_1_piece0 without replication took 2 ms
# 24/12/11 22:41:58 INFO SparkContext: Created broadcast 1 from broadcast at DAGScheduler.scala:1585
# 24/12/11 22:41:58 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 0 (MapPartitionsRDD[3] at csv at NativeMethodAccessorImpl.java:0) (first 15 tasks are for partitions Vector(0))
# 24/12/11 22:41:58 INFO TaskSchedulerImpl: Adding task set 0.0 with 1 tasks resource profile 0
# 24/12/11 22:41:58 DEBUG TaskSetManager: Epoch for TaskSet 0.0: 0
# 24/12/11 22:41:58 DEBUG TaskSetManager: Adding pending tasks took 2 ms
# 24/12/11 22:41:58 DEBUG TaskSetManager: Valid locality levels for TaskSet 0.0: NO_PREF, ANY
# 24/12/11 22:41:58 DEBUG TaskSchedulerImpl: parentName: , name: TaskSet_0.0, runningTasks: 0
# 24/12/11 22:41:58 DEBUG TaskSetManager: Valid locality levels for TaskSet 0.0: NO_PREF, ANY
# 24/12/11 22:41:58 INFO TaskSetManager: Starting task 0.0 in stage 0.0 (TID 0) (10.255.255.254, executor driver, partition 0, PROCESS_LOCAL, 9614 bytes)
# 24/12/11 22:41:58 DEBUG TaskSetManager: No tasks for locality level NO_PREF, so moving to locality level ANY
# 24/12/11 22:41:59 INFO Executor: Running task 0.0 in stage 0.0 (TID 0)
# 24/12/11 22:41:59 DEBUG ExecutorMetricsPoller: stageTCMP: (0, 0) -> 1
# 24/12/11 22:41:59 DEBUG BlockManager: Getting local block broadcast_1
# 24/12/11 22:41:59 DEBUG BlockManager: Level for block broadcast_1 is StorageLevel(disk, memory, deserialized, 1 replicas)
# 24/12/11 22:41:59 DEBUG CodeGenerator:
# /* 001 */ public Object generate(Object[] references) {
# /* 002 */   return new GeneratedIteratorForCodegenStage1(references);
# /* 003 */ }
# /* 004 */
# /* 005 */ // codegenStageId=1
# /* 006 */ final class GeneratedIteratorForCodegenStage1 extends org.apache.spark.sql.execution.BufferedRowIterator {
# /* 007 */   private Object[] references;
# /* 008 */   private scala.collection.Iterator[] inputs;
# /* 009 */   private scala.collection.Iterator inputadapter_input_0;
# /* 010 */   private org.apache.spark.sql.catalyst.expressions.codegen.UnsafeRowWriter[] filter_mutableStateArray_0 = new org.apache.spark.sql.catalyst.expressions.codegen.UnsafeRowWriter[1];
# /* 011 */
# /* 012 */   public GeneratedIteratorForCodegenStage1(Object[] references) {
# /* 013 */     this.references = references;
# /* 014 */   }
# /* 015 */
# /* 016 */   public void init(int index, scala.collection.Iterator[] inputs) {
# /* 017 */     partitionIndex = index;
# /* 018 */     this.inputs = inputs;
# /* 019 */     inputadapter_input_0 = inputs[0];
# /* 020 */     filter_mutableStateArray_0[0] = new org.apache.spark.sql.catalyst.expressions.codegen.UnsafeRowWriter(1, 32);
# /* 021 */
# /* 022 */   }
# /* 023 */
# /* 024 */   protected void processNext() throws java.io.IOException {
# /* 025 */     while ( inputadapter_input_0.hasNext()) {
# /* 026 */       InternalRow inputadapter_row_0 = (InternalRow) inputadapter_input_0.next();
# /* 027 */
# /* 028 */       do {
# /* 029 */         boolean inputadapter_isNull_0 = inputadapter_row_0.isNullAt(0);
# /* 030 */         UTF8String inputadapter_value_0 = inputadapter_isNull_0 ?
# /* 031 */         null : (inputadapter_row_0.getUTF8String(0));
# /* 032 */
# /* 033 */         boolean filter_isNull_0 = true;
# /* 034 */         boolean filter_value_0 = false;
# /* 035 */         boolean filter_isNull_2 = false;
# /* 036 */         UTF8String filter_value_2 = null;
# /* 037 */         if (inputadapter_isNull_0) {
# /* 038 */           filter_isNull_2 = true;
# /* 039 */         } else {
# /* 040 */           filter_value_2 = inputadapter_value_0.trim();
# /* 041 */         }
# /* 042 */         boolean filter_isNull_1 = filter_isNull_2;
# /* 043 */         int filter_value_1 = -1;
# /* 044 */
# /* 045 */         if (!filter_isNull_2) {
# /* 046 */           filter_value_1 = (filter_value_2).numChars();
# /* 047 */         }
# /* 048 */         if (!filter_isNull_1) {
# /* 049 */           filter_isNull_0 = false; // resultCode could change nullability.
# /* 050 */           filter_value_0 = filter_value_1 > 0;
# /* 051 */
# /* 052 */         }
# /* 053 */         if (filter_isNull_0 || !filter_value_0) continue;
# /* 054 */
# /* 055 */         ((org.apache.spark.sql.execution.metric.SQLMetric) references[0] /* numOutputRows */).add(1);
# /* 056 */
# /* 057 */         filter_mutableStateArray_0[0].reset();
# /* 058 */
# /* 059 */         filter_mutableStateArray_0[0].zeroOutNullBytes();
# /* 060 */
# /* 061 */         if (inputadapter_isNull_0) {
# /* 062 */           filter_mutableStateArray_0[0].setNullAt(0);
# /* 063 */         } else {
# /* 064 */           filter_mutableStateArray_0[0].write(0, inputadapter_value_0);
# /* 065 */         }
# /* 066 */         append((filter_mutableStateArray_0[0].getRow()));
# /* 067 */
# /* 068 */       } while(false);
# /* 069 */       if (shouldStop()) return;
# /* 070 */     }
# /* 071 */   }
# /* 072 */
# /* 073 */ }
#
# 24/12/11 22:41:59 INFO CodeGenerator: Code generated in 58.549379 ms
# 24/12/11 22:41:59 INFO FileScanRDD: Reading File path: file:///home/vuphamas/code/fraud/data/creditcard.csv, range: 0-19377882, partition values: [empty row]
# 24/12/11 22:41:59 DEBUG GenerateUnsafeProjection: code for input[0, string, true]:
# /* 001 */ public java.lang.Object generate(Object[] references) {
# /* 002 */   return new SpecificUnsafeProjection(references);
# /* 003 */ }
# /* 004 */
# /* 005 */ class SpecificUnsafeProjection extends org.apache.spark.sql.catalyst.expressions.UnsafeProjection {
# /* 006 */
# /* 007 */   private Object[] references;
# /* 008 */   private org.apache.spark.sql.catalyst.expressions.codegen.UnsafeRowWriter[] mutableStateArray_0 = new org.apache.spark.sql.catalyst.expressions.codegen.UnsafeRowWriter[1];
# /* 009 */
# /* 010 */   public SpecificUnsafeProjection(Object[] references) {
# /* 011 */     this.references = references;
# /* 012 */     mutableStateArray_0[0] = new org.apache.spark.sql.catalyst.expressions.codegen.UnsafeRowWriter(1, 32);
# /* 013 */
# /* 014 */   }
# /* 015 */
# /* 016 */   public void initialize(int partitionIndex) {
# /* 017 */
# /* 018 */   }
# /* 019 */
# /* 020 */   // Scala.Function1 need this
# /* 021 */   public java.lang.Object apply(java.lang.Object row) {
# /* 022 */     return apply((InternalRow) row);
# /* 023 */   }
# /* 024 */
# /* 025 */   public UnsafeRow apply(InternalRow i) {
# /* 026 */     mutableStateArray_0[0].reset();
# /* 027 */
# /* 028 */
# /* 029 */     mutableStateArray_0[0].zeroOutNullBytes();
# /* 030 */
# /* 031 */     boolean isNull_0 = i.isNullAt(0);
# /* 032 */     UTF8String value_0 = isNull_0 ?
# /* 033 */     null : (i.getUTF8String(0));
# /* 034 */     if (isNull_0) {
# /* 035 */       mutableStateArray_0[0].setNullAt(0);
# /* 036 */     } else {
# /* 037 */       mutableStateArray_0[0].write(0, value_0);
# /* 038 */     }
# /* 039 */     return (mutableStateArray_0[0].getRow());
# /* 040 */   }
# /* 041 */
# /* 042 */
# /* 043 */ }
#
# 24/12/11 22:41:59 DEBUG CodeGenerator:
# /* 001 */ public java.lang.Object generate(Object[] references) {
# /* 002 */   return new SpecificUnsafeProjection(references);
# /* 003 */ }
# /* 004 */
# /* 005 */ class SpecificUnsafeProjection extends org.apache.spark.sql.catalyst.expressions.UnsafeProjection {
# /* 006 */
# /* 007 */   private Object[] references;
# /* 008 */   private org.apache.spark.sql.catalyst.expressions.codegen.UnsafeRowWriter[] mutableStateArray_0 = new org.apache.spark.sql.catalyst.expressions.codegen.UnsafeRowWriter[1];
# /* 009 */
# /* 010 */   public SpecificUnsafeProjection(Object[] references) {
# /* 011 */     this.references = references;
# /* 012 */     mutableStateArray_0[0] = new org.apache.spark.sql.catalyst.expressions.codegen.UnsafeRowWriter(1, 32);
# /* 013 */
# /* 014 */   }
# /* 015 */
# /* 016 */   public void initialize(int partitionIndex) {
# /* 017 */
# /* 018 */   }
# /* 019 */
# /* 020 */   // Scala.Function1 need this
# /* 021 */   public java.lang.Object apply(java.lang.Object row) {
# /* 022 */     return apply((InternalRow) row);
# /* 023 */   }
# /* 024 */
# /* 025 */   public UnsafeRow apply(InternalRow i) {
# /* 026 */     mutableStateArray_0[0].reset();
# /* 027 */
# /* 028 */
# /* 029 */     mutableStateArray_0[0].zeroOutNullBytes();
# /* 030 */
# /* 031 */     boolean isNull_0 = i.isNullAt(0);
# /* 032 */     UTF8String value_0 = isNull_0 ?
# /* 033 */     null : (i.getUTF8String(0));
# /* 034 */     if (isNull_0) {
# /* 035 */       mutableStateArray_0[0].setNullAt(0);
# /* 036 */     } else {
# /* 037 */       mutableStateArray_0[0].write(0, value_0);
# /* 038 */     }
# /* 039 */     return (mutableStateArray_0[0].getRow());
# /* 040 */   }
# /* 041 */
# /* 042 */
# /* 043 */ }
#
# 24/12/11 22:41:59 INFO CodeGenerator: Code generated in 26.737286 ms
# 24/12/11 22:41:59 DEBUG BlockManager: Getting local block broadcast_0
# 24/12/11 22:41:59 DEBUG BlockManager: Level for block broadcast_0 is StorageLevel(disk, memory, deserialized, 1 replicas)
# 24/12/11 22:41:59 INFO Executor: Finished task 0.0 in stage 0.0 (TID 0). 1794 bytes result sent to driver
# 24/12/11 22:41:59 DEBUG ExecutorMetricsPoller: stageTCMP: (0, 0) -> 0
# 24/12/11 22:41:59 INFO TaskSetManager: Finished task 0.0 in stage 0.0 (TID 0) in 530 ms on 10.255.255.254 (executor driver) (1/1)
# 24/12/11 22:41:59 INFO TaskSchedulerImpl: Removed TaskSet 0.0, whose tasks have all completed, from pool
# 24/12/11 22:41:59 INFO DAGScheduler: ResultStage 0 (csv at NativeMethodAccessorImpl.java:0) finished in 0.691 s
# 24/12/11 22:41:59 DEBUG DAGScheduler: After removal of stage 0, remaining stages = 0
# 24/12/11 22:41:59 INFO DAGScheduler: Job 0 is finished. Cancelling potential speculative or zombie tasks for this job
# 24/12/11 22:41:59 INFO TaskSchedulerImpl: Killing all running tasks in stage 0: Stage finished
# 24/12/11 22:41:59 INFO DAGScheduler: Job 0 finished: csv at NativeMethodAccessorImpl.java:0, took 0.745213 s
# 24/12/11 22:41:59 DEBUG GenerateSafeProjection: code for input[0, string, true].toString:
# /* 001 */ public java.lang.Object generate(Object[] references) {
# /* 002 */   return new SpecificSafeProjection(references);
# /* 003 */ }
# /* 004 */
# /* 005 */ class SpecificSafeProjection extends org.apache.spark.sql.catalyst.expressions.codegen.BaseProjection {
# /* 006 */
# /* 007 */   private Object[] references;
# /* 008 */   private InternalRow mutableRow;
# /* 009 */
# /* 010 */
# /* 011 */   public SpecificSafeProjection(Object[] references) {
# /* 012 */     this.references = references;
# /* 013 */     mutableRow = (InternalRow) references[references.length - 1];
# /* 014 */
# /* 015 */   }
# /* 016 */
# /* 017 */   public void initialize(int partitionIndex) {
# /* 018 */
# /* 019 */   }
# /* 020 */
# /* 021 */   public java.lang.Object apply(java.lang.Object _i) {
# /* 022 */     InternalRow i = (InternalRow) _i;
# /* 023 */     boolean isNull_1 = i.isNullAt(0);
# /* 024 */     UTF8String value_1 = isNull_1 ?
# /* 025 */     null : (i.getUTF8String(0));
# /* 026 */     boolean isNull_0 = true;
# /* 027 */     java.lang.String value_0 = null;
# /* 028 */     if (!isNull_1) {
# /* 029 */       isNull_0 = false;
# /* 030 */       if (!isNull_0) {
# /* 031 */
# /* 032 */         Object funcResult_0 = null;
# /* 033 */         funcResult_0 = value_1.toString();
# /* 034 */         value_0 = (java.lang.String) funcResult_0;
# /* 035 */
# /* 036 */       }
# /* 037 */     }
# /* 038 */     if (isNull_0) {
# /* 039 */       mutableRow.setNullAt(0);
# /* 040 */     } else {
# /* 041 */
# /* 042 */       mutableRow.update(0, value_0);
# /* 043 */     }
# /* 044 */
# /* 045 */     return mutableRow;
# /* 046 */   }
# /* 047 */
# /* 048 */
# /* 049 */ }
#
# 24/12/11 22:41:59 DEBUG CodeGenerator:
# /* 001 */ public java.lang.Object generate(Object[] references) {
# /* 002 */   return new SpecificSafeProjection(references);
# /* 003 */ }
# /* 004 */
# /* 005 */ class SpecificSafeProjection extends org.apache.spark.sql.catalyst.expressions.codegen.BaseProjection {
# /* 006 */
# /* 007 */   private Object[] references;
# /* 008 */   private InternalRow mutableRow;
# /* 009 */
# /* 010 */
# /* 011 */   public SpecificSafeProjection(Object[] references) {
# /* 012 */     this.references = references;
# /* 013 */     mutableRow = (InternalRow) references[references.length - 1];
# /* 014 */
# /* 015 */   }
# /* 016 */
# /* 017 */   public void initialize(int partitionIndex) {
# /* 018 */
# /* 019 */   }
# /* 020 */
# /* 021 */   public java.lang.Object apply(java.lang.Object _i) {
# /* 022 */     InternalRow i = (InternalRow) _i;
# /* 023 */     boolean isNull_1 = i.isNullAt(0);
# /* 024 */     UTF8String value_1 = isNull_1 ?
# /* 025 */     null : (i.getUTF8String(0));
# /* 026 */     boolean isNull_0 = true;
# /* 027 */     java.lang.String value_0 = null;
# /* 028 */     if (!isNull_1) {
# /* 029 */       isNull_0 = false;
# /* 030 */       if (!isNull_0) {
# /* 031 */
# /* 032 */         Object funcResult_0 = null;
# /* 033 */         funcResult_0 = value_1.toString();
# /* 034 */         value_0 = (java.lang.String) funcResult_0;
# /* 035 */
# /* 036 */       }
# /* 037 */     }
# /* 038 */     if (isNull_0) {
# /* 039 */       mutableRow.setNullAt(0);
# /* 040 */     } else {
# /* 041 */
# /* 042 */       mutableRow.update(0, value_0);
# /* 043 */     }
# /* 044 */
# /* 045 */     return mutableRow;
# /* 046 */   }
# /* 047 */
# /* 048 */
# /* 049 */ }
#
# 24/12/11 22:41:59 INFO CodeGenerator: Code generated in 22.272551 ms
# 24/12/11 22:41:59 INFO FileSourceStrategy: Pushed Filters:
# 24/12/11 22:41:59 INFO FileSourceStrategy: Post-Scan Filters:
# 24/12/11 22:41:59 INFO MemoryStore: Block broadcast_2 stored as values in memory (estimated size 199.8 KiB, free 434.0 MiB)
# 24/12/11 22:41:59 DEBUG BlockManager: Put block broadcast_2 locally took 8 ms
# 24/12/11 22:41:59 DEBUG BlockManager: Putting block broadcast_2 without replication took 8 ms
# 24/12/11 22:41:59 INFO MemoryStore: Block broadcast_2_piece0 stored as bytes in memory (estimated size 34.4 KiB, free 433.9 MiB)
# 24/12/11 22:41:59 DEBUG BlockManagerMasterEndpoint: Updating block info on master broadcast_2_piece0 for BlockManagerId(driver, 10.255.255.254, 36101, None)
# 24/12/11 22:41:59 INFO BlockManagerInfo: Added broadcast_2_piece0 in memory on 10.255.255.254:36101 (size: 34.4 KiB, free: 434.3 MiB)
# 24/12/11 22:41:59 DEBUG BlockManagerMaster: Updated info of block broadcast_2_piece0
# 24/12/11 22:41:59 DEBUG BlockManager: Told master about block broadcast_2_piece0
# 24/12/11 22:41:59 DEBUG BlockManager: Put block broadcast_2_piece0 locally took 4 ms
# 24/12/11 22:41:59 DEBUG BlockManager: Putting block broadcast_2_piece0 without replication took 4 ms
# 24/12/11 22:41:59 INFO SparkContext: Created broadcast 2 from csv at NativeMethodAccessorImpl.java:0
# 24/12/11 22:41:59 INFO FileSourceScanExec: Planning scan with bin packing, max size: 19377882 bytes, open cost is considered as scanning 4194304 bytes.
# 24/12/11 22:41:59 DEBUG ClosureCleaner: Cleaning indylambda closure: $anonfun$rdd$1
# 24/12/11 22:41:59 DEBUG ClosureCleaner:  +++ indylambda closure ($anonfun$rdd$1) is now cleaned +++
# 24/12/11 22:41:59 DEBUG ClosureCleaner: Cleaning indylambda closure: $anonfun$inferFromDataset$2
# 24/12/11 22:41:59 DEBUG ClosureCleaner:  +++ indylambda closure ($anonfun$inferFromDataset$2) is now cleaned +++
# 24/12/11 22:41:59 DEBUG ClosureCleaner: Cleaning indylambda closure: $anonfun$infer$2
# 24/12/11 22:41:59 DEBUG ClosureCleaner:  +++ indylambda closure ($anonfun$infer$2) is now cleaned +++
# 24/12/11 22:41:59 DEBUG ClosureCleaner: Cleaning indylambda closure: $anonfun$infer$3
# 24/12/11 22:41:59 DEBUG ClosureCleaner:  +++ indylambda closure ($anonfun$infer$3) is now cleaned +++
# 24/12/11 22:41:59 DEBUG ClosureCleaner: Cleaning indylambda closure: $anonfun$runJob$6
# 24/12/11 22:41:59 DEBUG ClosureCleaner:  +++ indylambda closure ($anonfun$runJob$6) is now cleaned +++
# 24/12/11 22:41:59 INFO SparkContext: Starting job: csv at NativeMethodAccessorImpl.java:0
# 24/12/11 22:41:59 DEBUG DAGScheduler: eagerlyComputePartitionsForRddAndAncestors for RDD 9 took 0.000143 seconds
# 24/12/11 22:41:59 DEBUG DAGScheduler: Merging stage rdd profiles: Set()
# 24/12/11 22:41:59 INFO DAGScheduler: Got job 1 (csv at NativeMethodAccessorImpl.java:0) with 8 output partitions
# 24/12/11 22:41:59 INFO DAGScheduler: Final stage: ResultStage 1 (csv at NativeMethodAccessorImpl.java:0)
# 24/12/11 22:41:59 INFO DAGScheduler: Parents of final stage: List()
# 24/12/11 22:41:59 INFO DAGScheduler: Missing parents: List()
# 24/12/11 22:41:59 DEBUG DAGScheduler: submitStage(ResultStage 1 (name=csv at NativeMethodAccessorImpl.java:0;jobs=1))
# 24/12/11 22:41:59 DEBUG DAGScheduler: missing: List()
# 24/12/11 22:41:59 INFO DAGScheduler: Submitting ResultStage 1 (MapPartitionsRDD[9] at csv at NativeMethodAccessorImpl.java:0), which has no missing parents
# 24/12/11 22:41:59 DEBUG DAGScheduler: submitMissingTasks(ResultStage 1)
# 24/12/11 22:42:00 INFO MemoryStore: Block broadcast_3 stored as values in memory (estimated size 28.0 KiB, free 433.9 MiB)
# 24/12/11 22:42:00 DEBUG BlockManager: Put block broadcast_3 locally took 2 ms
# 24/12/11 22:42:00 DEBUG BlockManager: Putting block broadcast_3 without replication took 3 ms
# 24/12/11 22:42:00 INFO MemoryStore: Block broadcast_3_piece0 stored as bytes in memory (estimated size 12.8 KiB, free 433.9 MiB)
# 24/12/11 22:42:00 DEBUG BlockManagerMasterEndpoint: Updating block info on master broadcast_3_piece0 for BlockManagerId(driver, 10.255.255.254, 36101, None)
# 24/12/11 22:42:00 INFO BlockManagerInfo: Added broadcast_3_piece0 in memory on 10.255.255.254:36101 (size: 12.8 KiB, free: 434.3 MiB)
# 24/12/11 22:42:00 DEBUG BlockManagerMaster: Updated info of block broadcast_3_piece0
# 24/12/11 22:42:00 DEBUG BlockManager: Told master about block broadcast_3_piece0
# 24/12/11 22:42:00 DEBUG BlockManager: Put block broadcast_3_piece0 locally took 2 ms
# 24/12/11 22:42:00 DEBUG BlockManager: Putting block broadcast_3_piece0 without replication took 2 ms
# 24/12/11 22:42:00 INFO SparkContext: Created broadcast 3 from broadcast at DAGScheduler.scala:1585
# 24/12/11 22:42:00 INFO DAGScheduler: Submitting 8 missing tasks from ResultStage 1 (MapPartitionsRDD[9] at csv at NativeMethodAccessorImpl.java:0) (first 15 tasks are for partitions Vector(0, 1, 2, 3, 4, 5, 6, 7))
# 24/12/11 22:42:00 INFO TaskSchedulerImpl: Adding task set 1.0 with 8 tasks resource profile 0
# 24/12/11 22:42:00 DEBUG TaskSetManager: Epoch for TaskSet 1.0: 0
# 24/12/11 22:42:00 DEBUG TaskSetManager: Adding pending tasks took 0 ms
# 24/12/11 22:42:00 DEBUG TaskSetManager: Valid locality levels for TaskSet 1.0: NO_PREF, ANY
# 24/12/11 22:42:00 DEBUG TaskSchedulerImpl: parentName: , name: TaskSet_1.0, runningTasks: 0
# 24/12/11 22:42:00 INFO TaskSetManager: Starting task 0.0 in stage 1.0 (TID 1) (10.255.255.254, executor driver, partition 0, PROCESS_LOCAL, 9614 bytes)
# 24/12/11 22:42:00 INFO TaskSetManager: Starting task 1.0 in stage 1.0 (TID 2) (10.255.255.254, executor driver, partition 1, PROCESS_LOCAL, 9614 bytes)
# 24/12/11 22:42:00 INFO TaskSetManager: Starting task 2.0 in stage 1.0 (TID 3) (10.255.255.254, executor driver, partition 2, PROCESS_LOCAL, 9614 bytes)
# 24/12/11 22:42:00 INFO TaskSetManager: Starting task 3.0 in stage 1.0 (TID 4) (10.255.255.254, executor driver, partition 3, PROCESS_LOCAL, 9614 bytes)
# 24/12/11 22:42:00 INFO TaskSetManager: Starting task 4.0 in stage 1.0 (TID 5) (10.255.255.254, executor driver, partition 4, PROCESS_LOCAL, 9614 bytes)
# 24/12/11 22:42:00 INFO TaskSetManager: Starting task 5.0 in stage 1.0 (TID 6) (10.255.255.254, executor driver, partition 5, PROCESS_LOCAL, 9614 bytes)
# 24/12/11 22:42:00 INFO TaskSetManager: Starting task 6.0 in stage 1.0 (TID 7) (10.255.255.254, executor driver, partition 6, PROCESS_LOCAL, 9614 bytes)
# 24/12/11 22:42:00 INFO TaskSetManager: Starting task 7.0 in stage 1.0 (TID 8) (10.255.255.254, executor driver, partition 7, PROCESS_LOCAL, 9614 bytes)
# 24/12/11 22:42:00 INFO Executor: Running task 0.0 in stage 1.0 (TID 1)
# 24/12/11 22:42:00 DEBUG ExecutorMetricsPoller: stageTCMP: (1, 0) -> 1
# 24/12/11 22:42:00 DEBUG BlockManager: Getting local block broadcast_3
# 24/12/11 22:42:00 DEBUG BlockManager: Level for block broadcast_3 is StorageLevel(disk, memory, deserialized, 1 replicas)
# 24/12/11 22:42:00 INFO Executor: Running task 3.0 in stage 1.0 (TID 4)
# 24/12/11 22:42:00 DEBUG ExecutorMetricsPoller: stageTCMP: (1, 0) -> 2
# 24/12/11 22:42:00 INFO Executor: Running task 2.0 in stage 1.0 (TID 3)
# 24/12/11 22:42:00 INFO Executor: Running task 4.0 in stage 1.0 (TID 5)
# 24/12/11 22:42:00 DEBUG ExecutorMetricsPoller: stageTCMP: (1, 0) -> 3
# 24/12/11 22:42:00 DEBUG ExecutorMetricsPoller: stageTCMP: (1, 0) -> 4
# 24/12/11 22:42:00 INFO Executor: Running task 1.0 in stage 1.0 (TID 2)
# 24/12/11 22:42:00 INFO Executor: Running task 5.0 in stage 1.0 (TID 6)
# 24/12/11 22:42:00 DEBUG ExecutorMetricsPoller: stageTCMP: (1, 0) -> 5
# 24/12/11 22:42:00 INFO Executor: Running task 6.0 in stage 1.0 (TID 7)
# 24/12/11 22:42:00 DEBUG ExecutorMetricsPoller: stageTCMP: (1, 0) -> 6
# 24/12/11 22:42:00 INFO Executor: Running task 7.0 in stage 1.0 (TID 8)
# 24/12/11 22:42:00 DEBUG ExecutorMetricsPoller: stageTCMP: (1, 0) -> 7
# 24/12/11 22:42:00 DEBUG ExecutorMetricsPoller: stageTCMP: (1, 0) -> 8
# 24/12/11 22:42:00 DEBUG GenerateSafeProjection: code for input[0, string, true].toString:
# /* 001 */ public java.lang.Object generate(Object[] references) {
# /* 002 */   return new SpecificSafeProjection(references);
# /* 003 */ }
# /* 004 */
# /* 005 */ class SpecificSafeProjection extends org.apache.spark.sql.catalyst.expressions.codegen.BaseProjection {
# /* 006 */
# /* 007 */   private Object[] references;
# /* 008 */   private InternalRow mutableRow;
# /* 009 */
# /* 010 */
# /* 011 */   public SpecificSafeProjection(Object[] references) {
# /* 012 */     this.references = references;
# /* 013 */     mutableRow = (InternalRow) references[references.length - 1];
# /* 014 */
# /* 015 */   }
# /* 016 */
# /* 017 */   public void initialize(int partitionIndex) {
# /* 018 */
# /* 019 */   }
# /* 020 */
# /* 021 */   public java.lang.Object apply(java.lang.Object _i) {
# /* 022 */     InternalRow i = (InternalRow) _i;
# /* 023 */     boolean isNull_1 = i.isNullAt(0);
# /* 024 */     UTF8String value_1 = isNull_1 ?
# /* 025 */     null : (i.getUTF8String(0));
# /* 026 */     boolean isNull_0 = true;
# /* 027 */     java.lang.String value_0 = null;
# /* 028 */     if (!isNull_1) {
# /* 029 */       isNull_0 = false;
# /* 030 */       if (!isNull_0) {
# /* 031 */
# /* 032 */         Object funcResult_0 = null;
# /* 033 */         funcResult_0 = value_1.toString();
# /* 034 */         value_0 = (java.lang.String) funcResult_0;
# /* 035 */
# /* 036 */       }
# /* 037 */     }
# /* 038 */     if (isNull_0) {
# /* 039 */       mutableRow.setNullAt(0);
# /* 040 */     } else {
# /* 041 */
# /* 042 */       mutableRow.update(0, value_0);
# /* 043 */     }
# /* 044 */
# /* 045 */     return mutableRow;
# /* 046 */   }
# /* 047 */
# /* 048 */
# /* 049 */ }
#
# 24/12/11 22:42:00 DEBUG CodeGenerator:
# /* 001 */ public java.lang.Object generate(Object[] references) {
# /* 002 */   return new SpecificSafeProjection(references);
# /* 003 */ }
# /* 004 */
# /* 005 */ class SpecificSafeProjection extends org.apache.spark.sql.catalyst.expressions.codegen.BaseProjection {
# /* 006 */
# /* 007 */   private Object[] references;
# /* 008 */   private InternalRow mutableRow;
# /* 009 */
# /* 010 */
# /* 011 */   public SpecificSafeProjection(Object[] references) {
# /* 012 */     this.references = references;
# /* 013 */     mutableRow = (InternalRow) references[references.length - 1];
# /* 014 */
# /* 015 */   }
# /* 016 */
# /* 017 */   public void initialize(int partitionIndex) {
# /* 018 */
# /* 019 */   }
# /* 020 */
# /* 021 */   public java.lang.Object apply(java.lang.Object _i) {
# /* 022 */     InternalRow i = (InternalRow) _i;
# /* 023 */     boolean isNull_1 = i.isNullAt(0);
# /* 024 */     UTF8String value_1 = isNull_1 ?
# /* 025 */     null : (i.getUTF8String(0));
# /* 026 */     boolean isNull_0 = true;
# /* 027 */     java.lang.String value_0 = null;
# /* 028 */     if (!isNull_1) {
# /* 029 */       isNull_0 = false;
# /* 030 */       if (!isNull_0) {
# /* 031 */
# /* 032 */         Object funcResult_0 = null;
# /* 033 */         funcResult_0 = value_1.toString();
# /* 034 */         value_0 = (java.lang.String) funcResult_0;
# /* 035 */
# /* 036 */       }
# /* 037 */     }
# /* 038 */     if (isNull_0) {
# /* 039 */       mutableRow.setNullAt(0);
# /* 040 */     } else {
# /* 041 */
# /* 042 */       mutableRow.update(0, value_0);
# /* 043 */     }
# /* 044 */
# /* 045 */     return mutableRow;
# /* 046 */   }
# /* 047 */
# /* 048 */
# /* 049 */ }
#
# 24/12/11 22:42:00 DEBUG GenerateSafeProjection: code for input[0, string, true].toString:
# /* 001 */ public java.lang.Object generate(Object[] references) {
# /* 002 */   return new SpecificSafeProjection(references);
# /* 003 */ }
# /* 004 */
# /* 005 */ class SpecificSafeProjection extends org.apache.spark.sql.catalyst.expressions.codegen.BaseProjection {
# /* 006 */
# /* 007 */   private Object[] references;
# /* 008 */   private InternalRow mutableRow;
# /* 009 */
# /* 010 */
# /* 011 */   public SpecificSafeProjection(Object[] references) {
# /* 012 */     this.references = references;
# /* 013 */     mutableRow = (InternalRow) references[references.length - 1];
# /* 014 */
# /* 015 */   }
# /* 016 */
# /* 017 */   public void initialize(int partitionIndex) {
# /* 018 */
# /* 019 */   }
# /* 020 */
# /* 021 */   public java.lang.Object apply(java.lang.Object _i) {
# /* 022 */     InternalRow i = (InternalRow) _i;
# /* 023 */     boolean isNull_1 = i.isNullAt(0);
# /* 024 */     UTF8String value_1 = isNull_1 ?
# /* 025 */     null : (i.getUTF8String(0));
# /* 026 */     boolean isNull_0 = true;
# /* 027 */     java.lang.String value_0 = null;
# /* 028 */     if (!isNull_1) {
# /* 029 */       isNull_0 = false;
# /* 030 */       if (!isNull_0) {
# /* 031 */
# /* 032 */         Object funcResult_0 = null;
# /* 033 */         funcResult_0 = value_1.toString();
# /* 034 */         value_0 = (java.lang.String) funcResult_0;
# /* 035 */
# /* 036 */       }
# /* 037 */     }
# /* 038 */     if (isNull_0) {
# /* 039 */       mutableRow.setNullAt(0);
# /* 040 */     } else {
# /* 041 */
# /* 042 */       mutableRow.update(0, value_0);
# /* 043 */     }
# /* 044 */
# /* 045 */     return mutableRow;
# /* 046 */   }
# /* 047 */
# /* 048 */
# /* 049 */ }
#
# 24/12/11 22:42:00 DEBUG GenerateSafeProjection: code for input[0, string, true].toString:
# /* 001 */ public java.lang.Object generate(Object[] references) {
# /* 002 */   return new SpecificSafeProjection(references);
# /* 003 */ }
# /* 004 */
# /* 005 */ class SpecificSafeProjection extends org.apache.spark.sql.catalyst.expressions.codegen.BaseProjection {
# /* 006 */
# /* 007 */   private Object[] references;
# /* 008 */   private InternalRow mutableRow;
# /* 009 */
# /* 010 */
# /* 011 */   public SpecificSafeProjection(Object[] references) {
# /* 012 */     this.references = references;
# /* 013 */     mutableRow = (InternalRow) references[references.length - 1];
# /* 014 */
# /* 015 */   }
# /* 016 */
# /* 017 */   public void initialize(int partitionIndex) {
# /* 018 */
# /* 019 */   }
# /* 020 */
# /* 021 */   public java.lang.Object apply(java.lang.Object _i) {
# /* 022 */     InternalRow i = (InternalRow) _i;
# /* 023 */     boolean isNull_1 = i.isNullAt(0);
# /* 024 */     UTF8String value_1 = isNull_1 ?
# /* 025 */     null : (i.getUTF8String(0));
# /* 026 */     boolean isNull_0 = true;
# /* 027 */     java.lang.String value_0 = null;
# /* 028 */     if (!isNull_1) {
# /* 029 */       isNull_0 = false;
# /* 030 */       if (!isNull_0) {
# /* 031 */
# /* 032 */         Object funcResult_0 = null;
# /* 033 */         funcResult_0 = value_1.toString();
# /* 034 */         value_0 = (java.lang.String) funcResult_0;
# /* 035 */
# /* 036 */       }
# /* 037 */     }
# /* 038 */     if (isNull_0) {
# /* 039 */       mutableRow.setNullAt(0);
# /* 040 */     } else {
# /* 041 */
# /* 042 */       mutableRow.update(0, value_0);
# /* 043 */     }
# /* 044 */
# /* 045 */     return mutableRow;
# /* 046 */   }
# /* 047 */
# /* 048 */
# /* 049 */ }
#
# 24/12/11 22:42:00 DEBUG GenerateSafeProjection: code for input[0, string, true].toString:
# /* 001 */ public java.lang.Object generate(Object[] references) {
# /* 002 */   return new SpecificSafeProjection(references);
# /* 003 */ }
# /* 004 */
# /* 005 */ class SpecificSafeProjection extends org.apache.spark.sql.catalyst.expressions.codegen.BaseProjection {
# /* 006 */
# /* 007 */   private Object[] references;
# /* 008 */   private InternalRow mutableRow;
# /* 009 */
# /* 010 */
# /* 011 */   public SpecificSafeProjection(Object[] references) {
# /* 012 */     this.references = references;
# /* 013 */     mutableRow = (InternalRow) references[references.length - 1];
# /* 014 */
# /* 015 */   }
# /* 016 */
# /* 017 */   public void initialize(int partitionIndex) {
# /* 018 */
# /* 019 */   }
# /* 020 */
# /* 021 */   public java.lang.Object apply(java.lang.Object _i) {
# /* 022 */     InternalRow i = (InternalRow) _i;
# /* 023 */     boolean isNull_1 = i.isNullAt(0);
# /* 024 */     UTF8String value_1 = isNull_1 ?
# /* 025 */     null : (i.getUTF8String(0));
# /* 026 */     boolean isNull_0 = true;
# /* 027 */     java.lang.String value_0 = null;
# /* 028 */     if (!isNull_1) {
# /* 029 */       isNull_0 = false;
# /* 030 */       if (!isNull_0) {
# /* 031 */
# /* 032 */         Object funcResult_0 = null;
# /* 033 */         funcResult_0 = value_1.toString();
# /* 034 */         value_0 = (java.lang.String) funcResult_0;
# /* 035 */
# /* 036 */       }
# /* 037 */     }
# /* 038 */     if (isNull_0) {
# /* 039 */       mutableRow.setNullAt(0);
# /* 040 */     } else {
# /* 041 */
# /* 042 */       mutableRow.update(0, value_0);
# /* 043 */     }
# /* 044 */
# /* 045 */     return mutableRow;
# /* 046 */   }
# /* 047 */
# /* 048 */
# /* 049 */ }
#
# 24/12/11 22:42:00 DEBUG GenerateSafeProjection: code for input[0, string, true].toString:
# /* 001 */ public java.lang.Object generate(Object[] references) {
# /* 002 */   return new SpecificSafeProjection(references);
# /* 003 */ }
# /* 004 */
# /* 005 */ class SpecificSafeProjection extends org.apache.spark.sql.catalyst.expressions.codegen.BaseProjection {
# /* 006 */
# /* 007 */   private Object[] references;
# /* 008 */   private InternalRow mutableRow;
# /* 009 */
# /* 010 */
# /* 011 */   public SpecificSafeProjection(Object[] references) {
# /* 012 */     this.references = references;
# /* 013 */     mutableRow = (InternalRow) references[references.length - 1];
# /* 014 */
# /* 015 */   }
# /* 016 */
# /* 017 */   public void initialize(int partitionIndex) {
# /* 018 */
# /* 019 */   }
# /* 020 */
# /* 021 */   public java.lang.Object apply(java.lang.Object _i) {
# /* 022 */     InternalRow i = (InternalRow) _i;
# /* 023 */     boolean isNull_1 = i.isNullAt(0);
# /* 024 */     UTF8String value_1 = isNull_1 ?
# /* 025 */     null : (i.getUTF8String(0));
# /* 026 */     boolean isNull_0 = true;
# /* 027 */     java.lang.String value_0 = null;
# /* 028 */     if (!isNull_1) {
# /* 029 */       isNull_0 = false;
# /* 030 */       if (!isNull_0) {
# /* 031 */
# /* 032 */         Object funcResult_0 = null;
# /* 033 */         funcResult_0 = value_1.toString();
# /* 034 */         value_0 = (java.lang.String) funcResult_0;
# /* 035 */
# /* 036 */       }
# /* 037 */     }
# /* 038 */     if (isNull_0) {
# /* 039 */       mutableRow.setNullAt(0);
# /* 040 */     } else {
# /* 041 */
# /* 042 */       mutableRow.update(0, value_0);
# /* 043 */     }
# /* 044 */
# /* 045 */     return mutableRow;
# /* 046 */   }
# /* 047 */
# /* 048 */
# /* 049 */ }
#
# 24/12/11 22:42:00 DEBUG GenerateSafeProjection: code for input[0, string, true].toString:
# /* 001 */ public java.lang.Object generate(Object[] references) {
# /* 002 */   return new SpecificSafeProjection(references);
# /* 003 */ }
# /* 004 */
# /* 005 */ class SpecificSafeProjection extends org.apache.spark.sql.catalyst.expressions.codegen.BaseProjection {
# /* 006 */
# /* 007 */   private Object[] references;
# /* 008 */   private InternalRow mutableRow;
# /* 009 */
# /* 010 */
# /* 011 */   public SpecificSafeProjection(Object[] references) {
# /* 012 */     this.references = references;
# /* 013 */     mutableRow = (InternalRow) references[references.length - 1];
# /* 014 */
# /* 015 */   }
# /* 016 */
# /* 017 */   public void initialize(int partitionIndex) {
# /* 018 */
# /* 019 */   }
# /* 020 */
# /* 021 */   public java.lang.Object apply(java.lang.Object _i) {
# /* 022 */     InternalRow i = (InternalRow) _i;
# /* 023 */     boolean isNull_1 = i.isNullAt(0);
# /* 024 */     UTF8String value_1 = isNull_1 ?
# /* 025 */     null : (i.getUTF8String(0));
# /* 026 */     boolean isNull_0 = true;
# /* 027 */     java.lang.String value_0 = null;
# /* 028 */     if (!isNull_1) {
# /* 029 */       isNull_0 = false;
# ...
# 24/12/11 22:44:10 DEBUG BlockManagerStorageEndpoint: Sent response: true to 10.255.255.254:41047
# 24/12/11 22:44:10 DEBUG BlockManagerStorageEndpoint: Sent response: true to 10.255.255.254:41047
# 24/12/11 22:44:10 INFO TaskSetManager: Finished task 5.0 in stage 6.0 (TID 31) in 21618 ms on 10.255.255.254 (executor driver) (8/8)
# 24/12/11 22:44:10 DEBUG BlockManagerStorageEndpoint: removing block taskresult_31
# 24/12/11 22:44:10 DEBUG BlockManager: Removing block taskresult_31
# 24/12/11 22:44:10 DEBUG MemoryStore: Block taskresult_31 of size 8675457 dropped from memory (free 454922322)
# 24/12/11 22:44:10 DEBUG BlockManagerMasterEndpoint: Updating block info on master taskresult_31 for BlockManagerId(driver, 10.255.255.254, 36101, None)
# 24/12/11 22:44:10 INFO BlockManagerInfo: Removed taskresult_31 on 10.255.255.254:36101 in memory (size: 8.3 MiB, free: 434.3 MiB)
# 24/12/11 22:44:10 DEBUG BlockManagerMaster: Updated info of block taskresult_31
# 24/12/11 22:44:10 DEBUG BlockManager: Told master about block taskresult_31
# 24/12/11 22:44:10 INFO DAGScheduler: ResultStage 6 (toPandas at /tmp/ipykernel_1444995/993887692.py:64) finished in 21.744 s
# 24/12/11 22:44:10 INFO TaskSchedulerImpl: Removed TaskSet 6.0, whose tasks have all completed, from pool
# 24/12/11 22:44:10 DEBUG DAGScheduler: After removal of stage 6, remaining stages = 0
# 24/12/11 22:44:10 INFO DAGScheduler: Job 5 is finished. Cancelling potential speculative or zombie tasks for this job
# 24/12/11 22:44:10 INFO TaskSchedulerImpl: Killing all running tasks in stage 6: Stage finished
# 24/12/11 22:44:10 INFO DAGScheduler: Job 5 finished: toPandas at /tmp/ipykernel_1444995/993887692.py:64, took 21.759932 s
# 24/12/11 22:44:10 DEBUG BlockManagerStorageEndpoint: Done removing block taskresult_31, response is true
# 24/12/11 22:44:10 DEBUG BlockManagerStorageEndpoint: Sent response: true to 10.255.255.254:41047
# 24/12/11 22:44:14 DEBUG ExecutorMetricsPoller: removing (6, 0) from stageTCMP
# 24/12/11 22:44:19 DEBUG ContextCleaner: Got cleaning task CleanAccum(345)
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaning accumulator 345
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaned accumulator 345
# 24/12/11 22:44:19 DEBUG ContextCleaner: Got cleaning task CleanAccum(341)
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaning accumulator 341
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaned accumulator 341
# 24/12/11 22:44:19 DEBUG ContextCleaner: Got cleaning task CleanAccum(314)
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaning accumulator 314
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaned accumulator 314
# 24/12/11 22:44:19 DEBUG ContextCleaner: Got cleaning task CleanAccum(344)
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaning accumulator 344
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaned accumulator 344
# 24/12/11 22:44:19 DEBUG ContextCleaner: Got cleaning task CleanAccum(322)
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaning accumulator 322
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaned accumulator 322
# 24/12/11 22:44:19 DEBUG ContextCleaner: Got cleaning task CleanAccum(324)
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaning accumulator 324
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaned accumulator 324
# 24/12/11 22:44:19 DEBUG ContextCleaner: Got cleaning task CleanAccum(340)
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaning accumulator 340
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaned accumulator 340
# 24/12/11 22:44:19 DEBUG ContextCleaner: Got cleaning task CleanAccum(315)
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaning accumulator 315
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaned accumulator 315
# 24/12/11 22:44:19 DEBUG ContextCleaner: Got cleaning task CleanAccum(313)
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaning accumulator 313
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaned accumulator 313
# 24/12/11 22:44:19 DEBUG ContextCleaner: Got cleaning task CleanAccum(323)
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaning accumulator 323
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaned accumulator 323
# 24/12/11 22:44:19 DEBUG ContextCleaner: Got cleaning task CleanAccum(334)
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaning accumulator 334
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaned accumulator 334
# 24/12/11 22:44:19 DEBUG ContextCleaner: Got cleaning task CleanAccum(326)
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaning accumulator 326
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaned accumulator 326
# 24/12/11 22:44:19 DEBUG ContextCleaner: Got cleaning task CleanAccum(318)
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaning accumulator 318
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaned accumulator 318
# 24/12/11 22:44:19 DEBUG ContextCleaner: Got cleaning task CleanAccum(319)
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaning accumulator 319
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaned accumulator 319
# 24/12/11 22:44:19 DEBUG ContextCleaner: Got cleaning task CleanAccum(337)
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaning accumulator 337
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaned accumulator 337
# 24/12/11 22:44:19 DEBUG ContextCleaner: Got cleaning task CleanAccum(338)
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaning accumulator 338
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaned accumulator 338
# 24/12/11 22:44:19 DEBUG ContextCleaner: Got cleaning task CleanAccum(311)
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaning accumulator 311
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaned accumulator 311
# 24/12/11 22:44:19 DEBUG ContextCleaner: Got cleaning task CleanAccum(329)
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaning accumulator 329
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaned accumulator 329
# 24/12/11 22:44:19 DEBUG ContextCleaner: Got cleaning task CleanAccum(336)
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaning accumulator 336
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaned accumulator 336
# 24/12/11 22:44:19 DEBUG ContextCleaner: Got cleaning task CleanAccum(316)
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaning accumulator 316
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaned accumulator 316
# 24/12/11 22:44:19 DEBUG ContextCleaner: Got cleaning task CleanAccum(330)
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaning accumulator 330
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaned accumulator 330
# 24/12/11 22:44:19 DEBUG ContextCleaner: Got cleaning task CleanAccum(339)
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaning accumulator 339
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaned accumulator 339
# 24/12/11 22:44:19 DEBUG ContextCleaner: Got cleaning task CleanBroadcast(10)
# 24/12/11 22:44:19 DEBUG ContextCleaner: Cleaning broadcast 10
# 24/12/11 22:44:19 DEBUG TorrentBroadcast: Unpersisting TorrentBroadcast 10
# 24/12/11 22:44:19 DEBUG BlockManagerStorageEndpoint: removing broadcast 10
# 24/12/11 22:44:19 DEBUG BlockManager: Removing broadcast 10
# 24/12/11 22:44:19 DEBUG BlockManager: Removing block broadcast_10_piece0
# 24/12/11 22:44:19 DEBUG MemoryStore: Block broadcast_10_piece0 of size 28426 dropped from memory (free 454950748)
# 24/12/11 22:44:19 DEBUG BlockManagerMasterEndpoint: Updating block info on master broadcast_10_piece0 for BlockManagerId(driver, 10.255.255.254, 36101, None)
# 24/12/11 22:44:19 INFO BlockManagerInfo: Removed broadcast_10_piece0 on 10.255.255.254:36101 in memory (size: 27.8 KiB, free: 434.3 MiB)
# 24/12/11 22:44:19 DEBUG BlockManagerMaster: Updated info of block broadcast_10_piece0
# 24/12/11 22:44:19 DEBUG BlockManager: Told master about block broadcast_10_piece0
# 24/12/11 22:44:19 DEBUG BlockManager: Removing block broadcast_10
# 24/12/11 22:44:20 DEBUG MemoryStore: Block broadcast_10 of size 71784 dropped from memory (free 455022532)
# 24/12/11 22:44:20 DEBUG BlockManagerStorageEndpoint: Done removing broadcast 10, response is 0
# 24/12/11 22:44:20 DEBUG BlockManagerStorageEndpoint: Sent response: 0 to 10.255.255.254:41047
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaned broadcast 10
# 24/12/11 22:44:20 DEBUG ContextCleaner: Got cleaning task CleanAccum(328)
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaning accumulator 328
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaned accumulator 328
# 24/12/11 22:44:20 DEBUG ContextCleaner: Got cleaning task CleanAccum(312)
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaning accumulator 312
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaned accumulator 312
# 24/12/11 22:44:20 DEBUG ContextCleaner: Got cleaning task CleanAccum(332)
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaning accumulator 332
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaned accumulator 332
# 24/12/11 22:44:20 DEBUG ContextCleaner: Got cleaning task CleanAccum(333)
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaning accumulator 333
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaned accumulator 333
# 24/12/11 22:44:20 DEBUG ContextCleaner: Got cleaning task CleanAccum(317)
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaning accumulator 317
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaned accumulator 317
# 24/12/11 22:44:20 DEBUG ContextCleaner: Got cleaning task CleanAccum(325)
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaning accumulator 325
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaned accumulator 325
# 24/12/11 22:44:20 DEBUG ContextCleaner: Got cleaning task CleanAccum(320)
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaning accumulator 320
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaned accumulator 320
# 24/12/11 22:44:20 DEBUG ContextCleaner: Got cleaning task CleanAccum(342)
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaning accumulator 342
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaned accumulator 342
# 24/12/11 22:44:20 DEBUG ContextCleaner: Got cleaning task CleanAccum(343)
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaning accumulator 343
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaned accumulator 343
# 24/12/11 22:44:20 DEBUG ContextCleaner: Got cleaning task CleanAccum(321)
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaning accumulator 321
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaned accumulator 321
# 24/12/11 22:44:20 DEBUG ContextCleaner: Got cleaning task CleanAccum(331)
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaning accumulator 331
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaned accumulator 331
# 24/12/11 22:44:20 DEBUG ContextCleaner: Got cleaning task CleanAccum(254)
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaning accumulator 254
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaned accumulator 254
# 24/12/11 22:44:20 DEBUG ContextCleaner: Got cleaning task CleanAccum(327)
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaning accumulator 327
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaned accumulator 327
# 24/12/11 22:44:20 DEBUG ContextCleaner: Got cleaning task CleanAccum(242)
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaning accumulator 242
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaned accumulator 242
# 24/12/11 22:44:20 DEBUG ContextCleaner: Got cleaning task CleanAccum(243)
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaning accumulator 243
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaned accumulator 243
# 24/12/11 22:44:20 DEBUG ContextCleaner: Got cleaning task CleanAccum(250)
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaning accumulator 250
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaned accumulator 250
# 24/12/11 22:44:20 DEBUG ContextCleaner: Got cleaning task CleanAccum(249)
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaning accumulator 249
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaned accumulator 249
# 24/12/11 22:44:20 DEBUG ContextCleaner: Got cleaning task CleanAccum(253)
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaning accumulator 253
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaned accumulator 253
# 24/12/11 22:44:20 DEBUG ContextCleaner: Got cleaning task CleanAccum(255)
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaning accumulator 255
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaned accumulator 255
# 24/12/11 22:44:20 DEBUG ContextCleaner: Got cleaning task CleanAccum(248)
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaning accumulator 248
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaned accumulator 248
# 24/12/11 22:44:20 DEBUG ContextCleaner: Got cleaning task CleanAccum(252)
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaning accumulator 252
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaned accumulator 252
# 24/12/11 22:44:20 DEBUG ContextCleaner: Got cleaning task CleanBroadcast(7)
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaning broadcast 7
# 24/12/11 22:44:20 DEBUG TorrentBroadcast: Unpersisting TorrentBroadcast 7
# 24/12/11 22:44:20 DEBUG BlockManagerStorageEndpoint: removing broadcast 7
# 24/12/11 22:44:20 DEBUG BlockManager: Removing broadcast 7
# 24/12/11 22:44:20 DEBUG BlockManager: Removing block broadcast_7_piece0
# 24/12/11 22:44:20 DEBUG MemoryStore: Block broadcast_7_piece0 of size 35081 dropped from memory (free 455057613)
# 24/12/11 22:44:20 DEBUG BlockManagerMasterEndpoint: Updating block info on master broadcast_7_piece0 for BlockManagerId(driver, 10.255.255.254, 36101, None)
# 24/12/11 22:44:20 INFO BlockManagerInfo: Removed broadcast_7_piece0 on 10.255.255.254:36101 in memory (size: 34.3 KiB, free: 434.4 MiB)
# 24/12/11 22:44:20 DEBUG BlockManagerMaster: Updated info of block broadcast_7_piece0
# 24/12/11 22:44:20 DEBUG BlockManager: Told master about block broadcast_7_piece0
# 24/12/11 22:44:20 DEBUG BlockManager: Removing block broadcast_7
# 24/12/11 22:44:20 DEBUG MemoryStore: Block broadcast_7 of size 204360 dropped from memory (free 455261973)
# 24/12/11 22:44:20 DEBUG BlockManagerStorageEndpoint: Done removing broadcast 7, response is 0
# 24/12/11 22:44:20 DEBUG BlockManagerStorageEndpoint: Sent response: 0 to 10.255.255.254:41047
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaned broadcast 7
# 24/12/11 22:44:20 DEBUG ContextCleaner: Got cleaning task CleanAccum(256)
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaning accumulator 256
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaned accumulator 256
# 24/12/11 22:44:20 DEBUG ContextCleaner: Got cleaning task CleanAccum(251)
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaning accumulator 251
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaned accumulator 251
# 24/12/11 22:44:20 DEBUG ContextCleaner: Got cleaning task CleanAccum(257)
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaning accumulator 257
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaned accumulator 257
# 24/12/11 22:44:20 DEBUG ContextCleaner: Got cleaning task CleanAccum(335)
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaning accumulator 335
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaned accumulator 335
# 24/12/11 22:44:20 DEBUG ContextCleaner: Got cleaning task CleanAccum(244)
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaning accumulator 244
# 24/12/11 22:44:20 DEBUG ContextCleaner: Cleaned accumulator 244
# --- Fraud Detection Evaluation Metrics ---
#
# Confusion Matrix:
# [[281471   2844]
#  [   209    283]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99    284315
#            1       0.09      0.58      0.16       492
#
#     accuracy                           0.99    284807
#    macro avg       0.54      0.78      0.58    284807
# weighted avg       1.00      0.99      0.99    284807
#
#
# Area Under Precision-Recall Curve (AUPRC): 0.1091
# ROC AUC Score: 0.9496
#
# Fraud Detection Performance:
# Total Transactions: 284807
# Fraud Transactions: 492
# Non-Fraud Transactions: 284315
# Correctly Detected Fraud: 283 out of 492
# Fraud Detection Rate: 0.5752
# 24/12/11 22:44:40 INFO SparkContext: SparkContext is stopping with exitCode 0.
# 24/12/11 22:44:41 INFO SparkUI: Stopped Spark web UI at http://10.255.255.254:4041
# 24/12/11 22:44:41 INFO MapOutputTrackerMasterEndpoint: MapOutputTrackerMasterEndpoint stopped!
# 24/12/11 22:44:41 INFO MemoryStore: MemoryStore cleared
# 24/12/11 22:44:41 INFO BlockManager: BlockManager stopped
# 24/12/11 22:44:41 INFO BlockManagerMaster: BlockManagerMaster stopped
# 24/12/11 22:44:41 INFO OutputCommitCoordinator$OutputCommitCoordinatorEndpoint: OutputCommitCoordinator stopped!
# 24/12/11 22:44:41 INFO SparkContext: Successfully stopped SparkContext
# 24/12/11 22:44:43 DEBUG PoolThreadCache: Freed 12 thread-local buffer(s) from thread: shuffle-server-7-1
